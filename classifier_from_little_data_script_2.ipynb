# %%
run -i classifier_from_little_data_script_2.py
# Out:
# /usr/local/opt/pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# in jupyter notebook
# Train on 2000 samples, validate on 800 samples
# Epoch 1/3
# 2000/2000 [==============================] - 2s 1ms/step - loss: 0.7964 - acc: 0.7630 - val_loss: 0.2773 - val_acc: 0.8925
# Epoch 2/3
# 2000/2000 [==============================] - 2s 1ms/step - loss: 0.3697 - acc: 0.8440 - val_loss: 0.6378 - val_acc: 0.7550
# Epoch 3/3
# 2000/2000 [==============================] - 2s 1ms/step - loss: 0.3007 - acc: 0.8845 - val_loss: 0.2697 - val_acc: 0.8912
# done

# %%
train_history.history["acc"]

# %%
from classifier_from_little_data_script_2 import train_top_model
# Out:
# in jupyter notebook

# %%
train_top_model()
# Out:
# Train on 2000 samples, validate on 800 samples
# Epoch 1/3
# 2000/2000 [==============================] - 2s 1ms/step - loss: 0.6748 - acc: 0.7795 - val_loss: 0.6373 - val_acc: 0.7475
# Epoch 2/3
# 2000/2000 [==============================] - 2s 960us/step - loss: 0.3770 - acc: 0.8395 - val_loss: 0.4118 - val_acc: 0.8225
# Epoch 3/3
# 2000/2000 [==============================] - 2s 955us/step - loss: 0.2781 - acc: 0.8865 - val_loss: 0.2890 - val_acc: 0.8875
